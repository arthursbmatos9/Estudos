# %%
import pandas as pd

# %%
#importando bases a serem juntadas
base1 = pd.read_csv('/content/sample_data/test.csv')
base2 = pd.read_csv('/content/sample_data/gender_submission.csv')

# %%
#juntando as bases com base no mesmo identificador comum e qual atributo deve ser passado para a outra base
baseNova = pd.merge(base1, base2[['PassengerId', 'Survived']], on='PassengerId', how='left')

# %%
baseNova.to_csv('testUpdated.csv', index='false')
